# %% [markdown]
# # Aula 6 - Manipulação de Arquivos

# %% [markdown]
# Prof. Tiago Dias
#
# [Linkedin](https://www.linkedin.com/in/diasctiago/) | [Github](https://github.com/diasctiago) | [Blog](https://www.dadosaocubo.com/)

# %% [markdown]
# ## Manipulando arquivo de texto

# %% [markdown]
# [Documentação leitura e escrita de arquivos](https://docs.python.org/pt-br/3/tutorial/inputoutput.html?highlight=arquivo%20read#reading-and-writing-files)

# %%
# ler arquivo de texto

# %%
# imprimir a variável arquivo

# %%
# imprimir o conteúdo do arquivo em uma string

# %%
# criar um novo arquivo de texto

# %%
# imprimir a variável do novo arquivo

# %%
# imprimir o conteúdo do novo arquivo

# %%
# abrir o arquivo em modo escrita

# %%
# criando uma string

# %%
# Salvando a string no novo arquivo criado

# %%
# verificando o conteúdo do novo arquivo novamente

# %%
# alterar arquivo de texto completo

# %%
# verificando o conteúdo do novo arquivo alterado

# %%
# imprimir o conteúdo arquivo de texto incluindo varias linhas

# %%
# imprimir o conteúdo todo do arquivo

# %%
# imprimir o conteúdo do arquivo em uma lista

# %%
# adicionando conteúdo em uma lista de strings criando a lista

# %%
# adicionando conteúdo em uma lista de strings

# %%
# imprimir o conteúdo do arquivo em uma lista

# %%
# adicionar conteúdo no arquivo existente

# %%
# imprimir o conteúdo do arquivo em uma lista

# %% [markdown]
# ## Manipulando arquivos csv

# %% [markdown]
# [Documentação csv](https://docs.python.org/pt-br/3/library/csv.html?highlight=open%20file#module-csv)

# %%
# importando a biblioteca

# %%
# ler arquivo csv

# %%
# criar arquivo csv

# %%
# ler arquivo csv criado

# %%
# alterar arquivo csv incluindo novas linhas

# %%
# ler arquivo csv alterado

# %% [markdown]
# ## Manipulando arquivos json

# %% [markdown]
# [Documentação json](https://docs.python.org/pt-br/3/library/json.html?highlight=json#module-json)

# %%
# importando a biblioteca

# %%
# ler arquivo json

# %%
# verificando o tipo de dados carregado

# %%
# criar arquivo json

# %%
# ler arquivo json criado

# %%
# alterar arquivo json

# %%
# ler arquivo json alterado

# %% [markdown]
# ## Estudo de caso

# %% [markdown]
# Como fazer com que o sistema de vendas consiga salvar informações sobre produtos, usuários e vendas em disco.
