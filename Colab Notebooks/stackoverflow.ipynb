# %%
Words = [ 'fuel' , 'regular' , 'clause' , 'maximum' ]

KP = [  'fuel surcharge policy'  , 'Rsp' ,  'liability clause' , 'Volume' ] 

Output = [  'fuel surcharge'  , 'liability clause' ]

# %%
Output = []
for i,j in zip (Words, KP):
  print('i:{}, j:{}'.format(i,j))
  if i in j:
      Output.append (j)
  else:
      print ('NA')
# Out:
# i:fuel, j:fuel surcharge policy
# i:regular, j:Rsp
# NA
# i:clause, j:liability clause
# i:maximum, j:Volume
# NA

# %%
s = 'fuel surcharge policy'
s.find('fuel')
# Out:
# 0

# %%
Output = []
for i in Words:
  for j in KP:
    if j.find(i) != -1:
      Output.append (j)

print(Output)
# Out:
# ['fuel surcharge policy', 'liability clause']
