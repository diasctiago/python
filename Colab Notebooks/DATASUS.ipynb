# %% [markdown]
# Fonte: https://github.com/fccoelho/PySUS

# %%
import numpy as np
from statsmodels.stats.proportion import proportions_ztest

# %%
count = np.array([(230658 - 114460), (287845-144385)])
nobs = np.array([258845, 258845])
stat, pval = proportions_ztest(count, nobs)
print('{0:0.3}'.format(pval))
# Out:
# 0.0

# %%
# !pip install PySUS

# %%
from ftplib import FTP
import os
import pandas as pd
from pysus.online_data.SIH import download

# %%
dfTO = download('to', 2009, 10)

# %%
dfTO.head()
# Out:
#     UF_ZI ANO_CMPT MES_CMPT  ... ETNIA SEQUENCIA                REMESSA
# 0  170000     2009       10  ...             566  HE17000001N200910.DTS
# 1  170000     2009       10  ...             567  HE17000001N200910.DTS
# 2  170000     2009       10  ...             710  HE17000001N200910.DTS
# 3  170000     2009       10  ...             711  HE17000001N200910.DTS
# 4  170000     2009       10  ...             712  HE17000001N200910.DTS
#
# [5 rows x 86 columns]

# %%
from pysus.online_data.SIA import download

# %%
dfTO = download('to', 2009, 10)

# %%
dfTO[0].head()
# Out:
#   PA_CODUNI PA_GESTAO PA_CONDIC PA_UFMUN  ... PA_CODOCO PA_FLQT PA_FLER PA_ETNIA
# 0   2370581    170000        EP   170210  ...         1       K       0
# 1   2370581    170000        EP   170210  ...         1       K       0
# 2   2370581    170000        EP   170210  ...         1       K       0
# 3   5615283    170000        EP   170950  ...         1       R       0
# 4   5615283    170000        EP   170950  ...         1       K       0
#
# [5 rows x 54 columns]

# %%
dfTO[1].head()
# Out:
#     CODUNI  GESTAO CONDIC   UFMUN TPUPS  ... VL_APRES VL_APROV UFDIF MNDIF ETNIA
# 0  2786117  170000     EP  172100    05  ...    86.76    86.76     0     0
# 1  5098246  172100     MN  172100    39  ...   101.10   101.10     0     1
# 2  5098246  172100     MN  172100    39  ...   101.10   101.10     0     1
# 3  5098246  172100     MN  172100    39  ...   101.10   101.10     0     0
# 4  5098246  172100     MN  172100    39  ...   101.10   101.10     0     0
#
# [5 rows x 35 columns]
