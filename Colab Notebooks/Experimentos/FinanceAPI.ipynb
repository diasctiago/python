# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import yfinance as yf

from pandas_datareader import data as pdr

yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("BTC-USD", start="2022-01-01", end="2022-01-26")
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2022-01-01  46311.746094  47827.312500  46288.484375  47686.812500
# 2022-01-02  47680.925781  47881.406250  46856.937500  47345.218750
# 2022-01-03  47343.542969  47510.726562  45835.964844  46458.117188
# 2022-01-04  46458.851562  47406.546875  45752.464844  45897.574219
# 2022-01-05  45899.359375  46929.046875  42798.222656  43569.003906
# 2022-01-06  43565.511719  43748.718750  42645.539062  43160.929688
# 2022-01-07  43153.570312  43153.570312  41077.445312  41557.902344
# 2022-01-08  41561.464844  42228.941406  40672.277344  41733.941406
# 2022-01-09  41734.726562  42663.949219  41338.160156  41911.601562
# 2022-01-10  41910.230469  42199.484375  39796.570312  41821.261719
# 2022-01-11  41819.507812  43001.156250  41407.753906  42735.855469
# 2022-01-12  42742.179688  44135.367188  42528.988281  43949.101562
# ...

# %%
tickers = yf.Tickers('msft aapl goog MGLU3.SA')
# ^ returns a named tuple of Ticker objects

# %%
# access each ticker using (example)
#tickers.tickers['MGLU3.SA'].info

# %%
#tickers.tickers['BTC-USD'].history(period="1mo")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-8e0c01a4985a> in <module>
# ----> 1 tickers.tickers['BTC-USD'].history(period="1mo")
#
# KeyError: 'BTC-USD'

# %%
tickers.tickers['MGLU3.SA'].actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2012-05-02 00:00:00-03:00   0.000464         0.000
# 2014-02-21 00:00:00-03:00   0.002053         0.000
# 2014-04-23 00:00:00-03:00   0.003355         0.000
# 2015-01-15 00:00:00-02:00   0.002443         0.000
# 2015-04-28 00:00:00-03:00   0.003402         0.000
# 2015-10-01 00:00:00-03:00   0.000000         0.125
# 2017-04-26 00:00:00-03:00   0.003974         0.000
# 2017-09-05 00:00:00-03:00   0.000000         8.000
# 2017-12-20 00:00:00-02:00   0.012378         0.000
# 2018-04-17 00:00:00-03:00   0.008265         0.000
# 2019-01-02 00:00:00-02:00   0.018522         0.000
# 2019-04-16 00:00:00-03:00   0.011571         0.000
# 2019-08-06 00:00:00-03:00   0.000000         8.000
# 2019-10-08 00:00:00-03:00   0.018402         0.000
# 2020-01-02 00:00:00-03:00   0.008947         0.000
# 2020-04-14 00:00:00-03:00   0.179508         0.000
# 2020-07-31 00:00:00-03:00   0.023541         0.000
# ...

# %%
#tickers.tickers['MGLU3.SA'].recommendations

# %%
tickers.tickers['MGLU3.SA'].news
# Out:
# [{'uuid': '4ba87c48-3fbe-3e9c-b662-c142cda72f05',
#   'title': 'Form 8.3 - EMIS Group plc',
#   'publisher': 'Business Wire',
#   'link': 'https://finance.yahoo.com/news/form-8-3-emis-group-155300377.html',
#   'providerPublishTime': 1673625180,
#   'type': 'STORY',
#   'relatedTickers': ['EMIS.L']},
#  {'uuid': '08afa11b-1e9e-3e14-867d-a4e9ee0c2956',
#   'title': 'The Global Biotechnology Reagents Market is forecast to grow by $36,019.44 mn during 2022-2027, accelerating at a CAGR of 7.51% during the forecast period',
#   'publisher': 'GlobeNewswire',
#   'link': 'https://finance.yahoo.com/news/global-biotechnology-reagents-market-forecast-155200586.html',
#   'providerPublishTime': 1673625120,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/IN3_pUboxxFTZlP4bjcjcQ--~B/aD00MDA7dz00MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/globenewswire.com/4ce8962afb8a41766b626a7e61c8413f',
#      'width': 400,
#      'height': 400,
# ...

# %%
tickers.tickers['MGLU3.SA'].splits
# Out:
# Date
# 2015-10-01 00:00:00-03:00    0.125
# 2017-09-05 00:00:00-03:00    8.000
# 2019-08-06 00:00:00-03:00    8.000
# 2020-10-14 00:00:00-03:00    4.000
# Name: Stock Splits, dtype: float64

# %%
tickers.tickers['MGLU3.SA'].dividends
# Out:
# Date
# 2012-05-02 00:00:00-03:00    0.000464
# 2014-02-21 00:00:00-03:00    0.002053
# 2014-04-23 00:00:00-03:00    0.003355
# 2015-01-15 00:00:00-02:00    0.002443
# 2015-04-28 00:00:00-03:00    0.003402
# 2017-04-26 00:00:00-03:00    0.003974
# 2017-12-20 00:00:00-02:00    0.012378
# 2018-04-17 00:00:00-03:00    0.008265
# 2019-01-02 00:00:00-02:00    0.018522
# 2019-04-16 00:00:00-03:00    0.011571
# 2019-10-08 00:00:00-03:00    0.018402
# 2020-01-02 00:00:00-03:00    0.008947
# 2020-04-14 00:00:00-03:00    0.179508
# 2020-07-31 00:00:00-03:00    0.023541
# 2020-08-03 00:00:00-03:00    0.094176
# 2020-12-30 00:00:00-03:00    0.026301
# 2021-07-06 00:00:00-03:00    0.015494
# Name: Dividends, dtype: float64

# %%
#tickers.tickers['MGLU3.SA'].balance_sheet

# %%
#tickers.tickers['MGLU3.SA'].cashflow
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-7c8eff2760a1> in <module>
# ----> 1 tickers.tickers['MGLU3.SA'].cashflow
#
# /usr/local/lib/python3.8/dist-packages/yfinance/ticker.py in cashflow(self)
#     204     @property
#     205     def cashflow(self) -> _pd.DataFrame:
# --> 206         return self.cash_flow
#     207
#     208     @property
#
# /usr/local/lib/python3.8/dist-packages/yfinance/ticker.py in cash_flow(self)
#     196     @property
#     197     def cash_flow(self) -> _pd.DataFrame:
# --> 198         return self.get_cash_flow(pretty=True, freq="yearly")
#     199
#     200     @property
#
# /usr/local/lib/python3.8/dist-packages/yfinance/base.py in get_cash_flow(self, proxy, as_dict, pretty, freq, legacy)
#    1065             data = self._fundamentals.financials.get_cash_flow_scrape(freq=freq, proxy=proxy)
#    1066         else:
# ...

# %%
tickers.tickers['GOOG']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-1a81dac2302e> in <module>
# ----> 1 tickers.tickers['GOOG'].earning
#
# AttributeError: 'Ticker' object has no attribute 'earning'

# %%
tickers.tickers['MGLU3.SA'].financials
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-4ebccc4a1871> in <module>
# ----> 1 tickers.tickers['MGLU3.SA'].financials
#
# /usr/local/lib/python3.8/dist-packages/yfinance/ticker.py in financials(self)
#     172     @property
#     173     def financials(self) -> _pd.DataFrame:
# --> 174         return self.income_stmt
#     175
#     176     @property
#
# /usr/local/lib/python3.8/dist-packages/yfinance/ticker.py in income_stmt(self)
#     156     @property
#     157     def income_stmt(self) -> _pd.DataFrame:
# --> 158         return self.get_income_stmt(pretty=True)
#     159
#     160     @property
#
# /usr/local/lib/python3.8/dist-packages/yfinance/base.py in get_income_stmt(self, proxy, as_dict, pretty, freq, legacy)
#     990             data = self._fundamentals.financials.get_income_scrape(freq=freq, proxy=proxy)
#     991         else:
# ...

# %%
tickers.tickers['MGLU3.SA'].major_holders
# Out:
#         0                                      1
# 0  56.49%        % of Shares Held by All Insider
# 1  14.45%       % of Shares Held by Institutions
# 2  33.23%        % of Float Held by Institutions
# 3     305  Number of Institutions Holding Shares

# %%
tickers.tickers['MGLU3.SA'].institutional_holders

# %%
tickers.tickers['MGLU3.SA'].sustainability

# %%
tickers.tickers['MGLU3.SA'].calendar

# %%
tickers.tickers['MGLU3.SA'].options
# Out:
# ()
