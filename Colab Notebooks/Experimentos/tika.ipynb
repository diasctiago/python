# %% [markdown]
# <img src="https://raw.githubusercontent.com/dadosaocubo/classificacao/master/DadosAoCubo.png" alt="drawing" width="500"/>

# %% [markdown]
# [__Dados ao Cubo__](https://dadosaocubo.com/) by [__Tiago Dias__](https://www.linkedin.com/in/diasctiago/)

# %%
# !git clone https://github.com/dadosaocubo/pdf
# Out:
# Cloning into 'pdf'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.

# %%
# !pip install tika
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32893 sha256=df8c786c6ef45a6f62251bca85af15fc9378ad9d9a268adc7804527d71401b10
#   Stored in directory: /root/.cache/pip/wheels/ec/2b/38/58ff05467a742e32f67f5d0de048fa046e764e2fbb25ac93f3
# Successfully built tika
# ...

# %%
from tika import parser

# %%
raw = parser.from_file('/content/Fartura - Outorga.pdf')

# %%
type(raw)
# Out:
# dict

# %%
raw
# Out:
# {'metadata': {'Content-Type': 'application/pdf',
#   'Creation-Date': '2022-07-21T10:33:25Z',
#   'X-Parsed-By': ['org.apache.tika.parser.DefaultParser',
#    'org.apache.tika.parser.pdf.PDFParser'],
#   'X-TIKA:content_handler': 'ToTextContentHandler',
#   'X-TIKA:embedded_depth': '0',
#   'X-TIKA:parse_time_millis': '1326',
#   'access_permission:assemble_document': 'true',
#   'access_permission:can_modify': 'true',
#   'access_permission:can_print': 'true',
#   'access_permission:can_print_degraded': 'true',
#   'access_permission:extract_content': 'true',
#   'access_permission:extract_for_accessibility': 'true',
#   'access_permission:fill_in_form': 'true',
#   'access_permission:modify_annotations': 'true',
#   'created': '2022-07-21T10:33:25Z',
#   'dc:format': 'application/pdf; version=1.7',
#   'dcterms:created': '2022-07-21T10:33:25Z',
#   'meta:creation-date': '2022-07-21T10:33:25Z',
#   'pdf:PDFVersion': '1.7',
#   'pdf:charsPerPage': ['2359', '5015', '527', '627'],
# ...

# %%
raw['content']
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nGOVERNO DO ESTADO DO MARANHÃO\nSECRETARIA DE ESTADO DO MEIO AMBIENTE E RECURSOS NATURAIS - SEMA\n\nSuperintendência de Recursos Hídricos\n\nOUTORGA DE DIREITO DE USO\nVALIDADE: 22/07/2025\n\nPROCESSO Nº 20010001716/2020\n\nNº 0884507/2020\n\nNOME/RAZÃO SOCIAL: CPF/CNPJ:\n\nENDEREÇO: MUNICÍPIO:\nRodovia Rod Br 230, Km 20, N. 20, -, Zona Rural, 65975000 Estreito - MA\n\nCARACTERIZAÇÃO DA FONTE DE SUPRIMENTO\n\nELEMENTOS DA AUTORIZAÇÃO\n\nFINALIDADE DO USO DA ÁGUA:  Irrigação\nVAZÃO AUTORIZADA:  60.0 m³/h ou 600.0 m³/dia\nPERÍODO DE BOMBEAMENTO:  10.0 h/dia\n\nSuzano S.a 16.404.287/0177-16\n\nBACIA HIDROGRÁFICA:  Bacia hidrográfica do rio Tocantins\nMANANCIAL:  rio Feio\n\nMUNICÍPIO:  Estreito - MA\n\nPONTO DE CAPTAÇÃO\n\nLATITUDE:  6° 45' 28.81''\nLONGITUDE:  47° 26' 50.61''\n\nProfundidade:  --\n\nNível estático (NE):  --\n\nNível dinâmico (ND):  --\n\nVazão de teste:  --\n\nVazão de referência:  2932.0 m
# ...

# %%
print(raw['content'])
# Out:
# GOVERNO DO ESTADO DO MARANHÃO
# SECRETARIA ESTADUAL DE MEIO AMBIENTE E RECURSOS NATURAIS - SEMA
#
# SECRETARIA ADJUNTA DE RECURSOS AMBIENTAIS
# SUPERINTENDÊNCIA DE RECURSOS FLORESTAIS
#
# null
#
# OBSERVAÇÕES: Vide verso desta licença as Exigências / Recomendações.
#
# 4ª. VIA ARQUIVO2ª. VIA PROPRIETÁRIO
#
# O Secretário no uso  de  suas  atribuições  que  lhe conferem, expede  a presente  LICENÇA AMBIENTAL,
# que  deverá  ser  executada no imóvel  a  seguir  identificado, conforme os dados abaixo.
#
# Expedida em: Válida até:19/07/2022 18/02/2025
#
# IDENTIFICAÇÃO DO IMÓVEL
#
# 01. Processo nº: 16120016901/2016    e-Processos: 275690/2016
#
# 03. Endereço: --
#
# 04. Município: Bom Jesus das Selvas
#
# 05. Distrito: -- 06. CEP: -- 07. UF: MA
#
# 08. Proprietário: Suzano Papel E Celulose S.a
#
# 11. Endereço: Rodovia Rod 222 S/,n Km 245;margem Direita, -, Zona Rural
#
# 12. Município: Bom Jesus das Selvas
#
# 13. Distrito: -- 14. CEP: 65395000 15. UF: MA
#
# ...

# %%
# !pip install pytesseract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 3.1 MB 15.8 MB/s
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ...

# %%
# !pip install pdf2image

# %%
# !pip install wand
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 142 kB 14.8 MB/s
# ...

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 154 kB of archives.
# After this operation, 613 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 poppler-utils amd64 0.62.0-2ubuntu2.12 [154 kB]
# Fetched 154 kB in 1s (305 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 155680 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking poppler-utils (0.62.0-2ubuntu2.12) ...
# Setting up poppler-utils (0.62.0-2ubuntu2.12) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !apt-get install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 19 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 0s (28.3 MB/s)
# ...

# %%
# !apt-get install libmagickwand-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-rsvg-2.0 gsfonts imagemagick-6-common
#   libcairo-script-interpreter2 libcairo2-dev libcupsfilters1 libcupsimage2
#   libdjvulibre-dev libdjvulibre-text libdjvulibre21 libgdk-pixbuf2.0-dev
#   libgs9 libgs9-common libijs-0.35 libjbig2dec0 liblcms2-dev liblqr-1-0
#   liblqr-1-0-dev libmagickcore-6-arch-config libmagickcore-6-headers
#   libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra libmagickcore-6.q16-dev
#   libmagickwand-6-headers libmagickwand-6.q16-3 libmagickwand-6.q16-dev
#   libpixman-1-dev librsvg2-dev libwmf-dev libwmf0.2-7 libxcb-shm0-dev
#   poppler-data
# Suggested packages:
# ...

# %%
import os
from PIL import Image
from pdf2image import convert_from_path
import pytesseract

# %%
import os
import io
from PIL import Image
import pytesseract
from wand.image import Image as wi
import gc



pdf=wi(filename='Agro.jpg',resolution=500)
pdfImg=pdf.convert('PNG')

# %%
pdfImg
# Out:
# <wand.image.Image: 5ade4b3 'PNG' (496x702)>

# %%
pdf
# Out:
# <wand.image.Image: 5ade4b3 'JPEG' (496x702)>

# %%
filePath = '/content/pdf/sample.pdf'
doc = convert_from_path(filePath,2000)
path, fileName = os.path.split(filePath)
fileBaseName, fileExtension = os.path.splitext(fileName)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-65-1bb1f77af8a9> in <module>()
#       1 filePath = '/content/pdf/sample.pdf'
# ----> 2 doc = convert_from_path(filePath,2000)
#       3 path, fileName = os.path.split(filePath)
#       4 fileBaseName, fileExtension = os.path.splitext(fileName)
#       5
#
# /usr/local/lib/python3.7/dist-packages/pdf2image/pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#     220             )
#     221         else:
# --> 222             images += parse_buffer_func(data)
#     223
#     224     if auto_temp_dir:
#
# /usr/local/lib/python3.7/dist-packages/pdf2image/parsers.py in parse_buffer_to_ppm(data)
# ...

# %%
for page_number, page_data in enumerate(doc):
    txt = pytesseract.image_to_string(Image.fromarray(page_data)).encode("utf-8")
    print("Page # {} - {}".format(str(page_number),txt))

# %%
# import module
from pdf2image import convert_from_path

# %%
pages = convert_from_path('Nossa.pdf', 2000)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-41-3e80305061e1> in <module>()
# ----> 1 pages = convert_from_path('Nossa.pdf', 2000)
#       2
#
# /usr/local/lib/python3.7/dist-packages/pdf2image/pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#     220             )
#     221         else:
# --> 222             images += parse_buffer_func(data)
#     223
#     224     if auto_temp_dir:
#
# /usr/local/lib/python3.7/dist-packages/pdf2image/parsers.py in parse_buffer_to_ppm(data)
#      19         size_x, size_y = tuple(size.split(b" "))
#      20         file_size = len(code) + len(size) + len(rgb) + 3 + int(size_x) * int(size_y) * 3
# ...

# %%
for i in range(len(pages)):
  pages[i].save('page'+ str(i) +'.jpg', 'JPEG')

# %%
from PIL import Image # Importando o módulo Pillow para abrir a imagem no script

import pytesseract # Módulo para a utilização da tecnologia OCR

# %%
print( pytesseract.image_to_string( pdfImg ) ) # Extraindo o texto da imagem
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-4ac00f141664> in <module>()
# ----> 1 print( pytesseract.image_to_string( pdfImg ) ) # Extraindo o texto da imagem
#
# /usr/local/lib/python3.7/dist-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     418         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     419         Output.STRING: lambda: run_and_get_output(*args),
# --> 420     }[output_type]()
#     421
#     422
#
# /usr/local/lib/python3.7/dist-packages/pytesseract/pytesseract.py in <lambda>()
#     417         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     418         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 419         Output.STRING: lambda: run_and_get_output(*args),
#     420     }[output_type]()
#     421
#
# ...

# %%
txt = pytesseract.image_to_string(Image.fromarray('/content/Meinara.jpeg')).encode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-43adb857e2d2> in <module>()
# ----> 1 txt = pytesseract.image_to_string(Image.fromarray('/content/Meinara.jpeg')).encode("utf-8")
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in fromarray(obj, mode)
#    2702         from . import ImageQt
#    2703
# -> 2704         if not ImageQt.qt_is_installed:
#    2705             raise ImportError("Qt bindings are not installed")
#    2706         return ImageQt.toqimage(self)
#
# AttributeError: 'str' object has no attribute '__array_interface__'
