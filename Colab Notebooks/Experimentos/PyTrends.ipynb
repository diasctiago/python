# %%
# !pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16126 sha256=ce021c621bfb82398a81c71d15f64ec9be54a9044a0915b9df259ce22133f35a
#   Stored in directory: /root/.cache/pip/wheels/07/6f/5c/8174f98dec1bfbc7d5da4092854afcbcff4b26c3d9b66b5183
# Successfully built pytrends
# ...

# %%
from pytrends.request import TrendReq
import pandas as pd

pytrends = TrendReq(hl='pt-BR', tz=360)

# %%
pytrends.trending_searches(pn='brazil') # trending searches in real time for Brasil
# Out:
#                                          0
# 0                         Setembro Amarelo
# 1                         Gabriel Monteiro
# 2                                     Ipec
# 3                            Setembro 2022
# 4                    The Last of Us Part 1
# 5                     West Ham x Tottenham
# 6                                Liverpool
# 7                  Independiente del Valle
# 8                                 Ines Rau
# 9                                 Juventus
# 10                    Dia da Nutricionista
# 11                          Mega-Sena 2515
# 12                                  Bayern
# 13                                Setembro
# 14                                  Napoli
# 15                         Serena Williams
# 16                        Bolsonaro.com.br
# 17                                Londrina
# 18                                    Star
# 19  Dia do Profissional de Educação Física

# %%
pytrends.realtime_trending_searches(pn='BR').head() # realtime search trends for United States
# Out:
#                                                title  \
# 0  Fundo de Financiamento ao Estudante do Ensino ...
# 1  Atalanta B.C., Torino F.C., Serie A, Live tele...
# 2  Manchester United F.C., Cristiano Ronaldo, Pre...
# 3  Harry Styles, São Paulo, Chicken nugget, One D...
# 4  Leandro Hassum, Netflix, Maurício Manfrini, Jú...
#
#                                          entityNames
# 0  [Fundo de Financiamento ao Estudante do Ensino...
# 1  [Atalanta B.C., Torino F.C., Serie A, Live tel...
# 2  [Manchester United F.C., Cristiano Ronaldo, Pr...
# 3  [Harry Styles, São Paulo, Chicken nugget, One ...
# 4  [Leandro Hassum, Netflix, Maurício Manfrini, J...

# %%
pytrends.realtime_trending_searches(pn='BR').head(1).values # realtime search trends for United States
# Out:
# array([['Fundo de Financiamento ao Estudante do Ensino Superior, Caixa Econômica Federal, Student, Discounting',
#         list(['Fundo de Financiamento ao Estudante do Ensino Superior', 'Caixa Econômica Federal', 'Student', 'Discounting'])]],
#       dtype=object)

# %%
pytrends.related_topics()
# Out:
# {}

# %%
pytrends.related_queries()
# Out:
# {}

# %%
keyword = 'Google'
pytrends.suggestions(keyword)
# Out:
# [{'mid': '/m/045c7b', 'title': 'Google', 'type': 'Empresa'},
#  {'mid': '/m/025sndk', 'title': 'Google Tradutor', 'type': 'Website'},
#  {'mid': '/m/02q_bk', 'title': 'Gmail', 'type': 'Site'},
#  {'mid': '/m/055t58', 'title': 'Google Maps', 'type': 'Assunto'},
#  {'mid': '/m/010pkp62', 'title': 'Google Classroom', 'type': 'Assunto'}]

# %%
pytrends.categories()
# Out:
# {'children': [{'children': [{'children': [{'name': 'Animais domésticos exóticos',
#        'id': 607},
#       {'name': 'Cães', 'id': 886},
#       {'name': 'Cavalos', 'id': 888},
#       {'name': 'Coelhos e roedores', 'id': 889},
#       {'name': 'Gatos', 'id': 885},
#       {'name': 'Pássaros', 'id': 884},
#       {'name': 'Peixe e aquário', 'id': 887},
#       {'name': 'Répteis e anfíbios', 'id': 890}],
#      'name': 'Animais de estimação',
#      'id': 563},
#     {'children': [{'name': 'Bem-estar animal', 'id': 883},
#       {'name': 'Comida e suprimentos para animais de estimação', 'id': 379},
#       {'name': 'Veterinários', 'id': 380}],
#      'name': 'Produtos e serviços para animais',
#      'id': 882},
#     {'children': [{'name': 'Insetos e entomologia', 'id': 1278},
#       {'name': 'Zoológicos, aquários, preservação', 'id': 1009}],
#      'name': 'Vida selvagem',
#      'id': 119}],
#    'name': 'Animais de estimação e animais',
#    'id': 66},
# ...

# %%
pytrends.trending_searches(pn='brazil') # trending searches in real time for Brasil
# Out:
#                                          0
# 0                         Setembro Amarelo
# 1                         Gabriel Monteiro
# 2                                     Ipec
# 3                            Setembro 2022
# 4                    The Last of Us Part 1
# 5                     West Ham x Tottenham
# 6                                Liverpool
# 7                  Independiente del Valle
# 8                                 Ines Rau
# 9                                 Juventus
# 10                    Dia da Nutricionista
# 11                          Mega-Sena 2515
# 12                                  Bayern
# 13                                Setembro
# 14                                  Napoli
# 15                         Serena Williams
# 16                        Bolsonaro.com.br
# 17                                Londrina
# 18                                    Star
# 19  Dia do Profissional de Educação Física

# %%
kw_list = ['Setembro Amarelo']
pytrends.build_payload(kw_list, cat=0, timeframe='today 3-m', geo='BR')

# %%
pytrends.related_topics()
# Out:
# {'Setembro Amarelo': {'rising':      value     formattedValue  \
#   0   236950  Aumento repentino
#   1   180100  Aumento repentino
#   2   150050  Aumento repentino
#   3   135900  Aumento repentino
#   4   110550  Aumento repentino
#   5    89750  Aumento repentino
#   6    79900  Aumento repentino
#   7    61900  Aumento repentino
#   8    47500  Aumento repentino
#   9    46500  Aumento repentino
#   10     130          Mais 130%
#   11      70           Mais 70%
#
#                                                    link    topic_mid  \
#   0   /trends/explore?q=/m/03jzl9&date=today+3-m&geo=BR    /m/03jzl9
#   1   /trends/explore?q=/m/02rfdq&date=today+3-m&geo=BR    /m/02rfdq
#   2   /trends/explore?q=/m/06wbrv5&date=today+3-m&ge...   /m/06wbrv5
#   3   /trends/explore?q=/m/03x69g&date=today+3-m&geo=BR    /m/03x69g
#   4   /trends/explore?q=/m/0dprt0&date=today+3-m&geo=BR    /m/0dprt0
#   5   /trends/explore?q=/m/03qsdpk&date=today+3-m&ge...   /m/03qsdpk
# ...

# %%
dp_df = pytrends.suggestions('Setembro Amarelo')
dp_df = pd.DataFrame(dp_df)
dp_df
# Out:
#              mid             title     type
# 0  /g/11fylsq5w_  Setembro Amarelo  Assunto
# 1  /g/11gf9fshz_  Setembro Amarelo  Assunto

# %%
pytrends.top_charts(2021-5, hl='pt-BR', tz=360, geo='BR')
# Out:
#                       title exploreQuery
# 0                Pokemon GO
# 1  Jogos Olímpicos Rio 2016
# 2        Big Brother Brasil
# 3               Chapecoense
# 4     Tabela do Brasileirão
# 5        Domingos Montagner
# 6             Eleições 2016
# 7                      Enem
# 8                      Sisu
# 9                  iPhone 7

# %%
# !pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from googleapiclient.discovery import build
my_api_key = "AIzaSyDTHB_eAuLWnpD_CLkkgjOSD6JRlp1wOJg"
my_cse_id = "d766b4d085eb240b6"
def google_search (search_term, api_key, cse_id, **kwargs):
  service = build ("customsearch", "v1", developerKey = api_key) # nome e versão da Custom Search API
  res = service.cse (). list (q = search_term, cx = cse_id, ** kwargs) .execute ()
  return res

# %%
busca = google_search ('Dados ao Cubo', my_api_key, my_cse_id)

# %%
busca.keys()
# Out:
# dict_keys(['kind', 'url', 'queries', 'context', 'searchInformation', 'items'])

# %%
len(busca['items'])
# Out:
# 10

# %%
busca['items']
# Out:
# [{'kind': 'customsearch#result',
#   'title': 'Dados ao Cubo - Tudo sobre o mundo de dados!',
#   'htmlTitle': '<b>Dados ao Cubo</b> - Tudo sobre o mundo de dados!',
#   'link': 'https://dadosaocubo.com/',
#   'displayLink': 'dadosaocubo.com',
#   'snippet': 'Dados ao Cubo é do mundo de dados, aqui compartilhamos conhecimentos relacionados a Business Intelligence, Data Science e Machine Learning.',
#   'htmlSnippet': '<b>Dados ao Cubo</b> é do mundo de dados, aqui compartilhamos conhecimentos relacionados a Business Intelligence, Data Science e Machine Learning.',
#   'cacheId': 'RmIg7rphDVAJ',
#   'formattedUrl': 'https://dadosaocubo.com/',
#   'htmlFormattedUrl': 'https://<b>dadosaocubo</b>.com/',
#   'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcThdpSWNgsrAKSCWG8jgNdwASasuj3s6xUodILcO0yL4h_tGkH9h-r7Zn4',
#      'width': '270',
#      'height': '187'}],
#    'metatags': [{'viewport': 'width=device-width, initial-scale=1',
# ...
